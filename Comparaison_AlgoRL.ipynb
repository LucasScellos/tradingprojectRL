# %%
import trading_gym as tg
from stable_baselines3 import A2C,PPO,DQN

# %%
amzn_data = tg.recuperation_donnee(start="01/01/2017",end="01/04/2022",interval="1d")
print("Nb donnée : ",len(amzn_data), amzn_data.head())
env_amz = tg.creation_env(df=amzn_data, frame_bound=(15,1000))
model_A2C = tg.entrainement(env_amz, algo=A2C, timesteps = 100_000)
model_PPO = tg.entrainement(env_amz, algo=PPO, timesteps = 100_000)
model_DQN = tg.entrainement(env_amz, algo=DQN, timesteps = 100_000)
# Out:
# Nb donnée :  1260                   Open        High         Low       Close      Volume
# Date
# 2017-01-03  757.919983  758.760010  747.700012  753.669983  753.669983
# 2017-01-04  758.390015  759.679993  754.200012  757.179993  757.179993
# 2017-01-05  761.549988  782.400024  760.260010  780.450012  780.450012
# 2017-01-06  782.359985  799.440002  778.479980  795.989990  795.989990
# 2017-01-09  798.000000  801.770020  791.770020  796.919983  796.919983
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 413      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.662   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 38.7     |
# |    value_loss         | 3.84e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 293      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 5.86     |
# |    value_loss         | 74.8     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.67    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 15.1     |
# |    value_loss         | 3.49e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 400      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.681   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0476  |
# |    value_loss         | 0.00845  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 500       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -0.69     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 28.6      |
# |    value_loss         | 1.85e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 453      |
# |    iterations         | 600      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.554    |
# |    value_loss         | 0.92     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 475      |
# |    iterations         | 700      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.0717  |
# |    value_loss         | 0.0158   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 491      |
# |    iterations         | 800      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.883   |
# |    value_loss         | 21.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 900      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 14.5     |
# |    value_loss         | 450      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 1000     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.807   |
# |    value_loss         | 1.72     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 528      |
# |    iterations         | 1100     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -24.2    |
# |    value_loss         | 1.44e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 539      |
# |    iterations         | 1200     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.29    |
# |    value_loss         | 0.351    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 548      |
# |    iterations         | 1300     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -4.87    |
# |    value_loss         | 120      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 556       |
# |    iterations         | 1400      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.651    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 0.661     |
# |    value_loss         | 2.17      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 562       |
# |    iterations         | 1500      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.69     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 4.58      |
# |    value_loss         | 110       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 567      |
# |    iterations         | 1600     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.883    |
# |    value_loss         | 3.03     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 566      |
# |    iterations         | 1700     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -7.08    |
# |    value_loss         | 125      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 571      |
# |    iterations         | 1800     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -10.7    |
# |    value_loss         | 400      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 577      |
# |    iterations         | 1900     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0865  |
# |    value_loss         | 0.0147   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 582      |
# |    iterations         | 2000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -7.04    |
# |    value_loss         | 107      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 587      |
# |    iterations         | 2100     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.676   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 8.47     |
# |    value_loss         | 285      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 591      |
# |    iterations         | 2200     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -4.38    |
# |    value_loss         | 95.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 595      |
# |    iterations         | 2300     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0708  |
# |    value_loss         | 0.0161   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 599       |
# |    iterations         | 2400      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.693    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -5.74     |
# |    value_loss         | 86.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 2500      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.677    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | 18.4      |
# |    value_loss         | 1.01e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 603      |
# |    iterations         | 2600     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.681   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 10.6     |
# |    value_loss         | 328      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 2700      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.689    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -0.857    |
# |    value_loss         | 25        |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 604       |
# |    iterations         | 2800      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.684    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -9.86     |
# |    value_loss         | 262       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 2900     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -9.85    |
# |    value_loss         | 292      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 610      |
# |    iterations         | 3000     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 5.71     |
# |    value_loss         | 110      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 613      |
# |    iterations         | 3100     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 2.46     |
# |    value_loss         | 23       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 3200     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 8.28     |
# |    value_loss         | 359      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 3300     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 14.9     |
# |    value_loss         | 574      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 619       |
# |    iterations         | 3400      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.687    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -1.16     |
# |    value_loss         | 3.86      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 620      |
# |    iterations         | 3500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.662   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 38.4     |
# |    value_loss         | 7.73e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 622      |
# |    iterations         | 3600     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 1.5      |
# |    value_loss         | 37.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 624      |
# |    iterations         | 3700     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.674   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -49.5    |
# |    value_loss         | 5.4e+03  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 625      |
# |    iterations         | 3800     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 9.4      |
# |    value_loss         | 304      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 626       |
# |    iterations         | 3900      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.665    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | 3.48      |
# |    value_loss         | 272       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 628       |
# |    iterations         | 4000      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.676    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 30.7      |
# |    value_loss         | 2.71e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 628      |
# |    iterations         | 4100     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.668   |
# |    explained_variance | 2.38e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 30.3     |
# |    value_loss         | 2.14e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 627      |
# |    iterations         | 4200     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.143   |
# |    value_loss         | 0.0646   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 628      |
# |    iterations         | 4300     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 14       |
# |    value_loss         | 672      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 629      |
# |    iterations         | 4400     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.677   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -2.16    |
# |    value_loss         | 21.8     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 631      |
# |    iterations         | 4500     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.688   |
# |    explained_variance | 2.38e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 30.8     |
# |    value_loss         | 1.85e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 632      |
# |    iterations         | 4600     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -16.2    |
# |    value_loss         | 691      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 633       |
# |    iterations         | 4700      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.689    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | 49.4      |
# |    value_loss         | 5.32e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 633      |
# |    iterations         | 4800     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -2.83    |
# |    value_loss         | 21.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 635      |
# |    iterations         | 4900     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -5.26    |
# |    value_loss         | 294      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 634       |
# |    iterations         | 5000      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.693    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -2.37     |
# |    value_loss         | 15        |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 635      |
# |    iterations         | 5100     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.163   |
# |    value_loss         | 0.0823   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 633      |
# |    iterations         | 5200     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.12     |
# |    value_loss         | 92.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 633      |
# |    iterations         | 5300     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -57.5    |
# |    value_loss         | 1.02e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 5400     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -27.9    |
# |    value_loss         | 1.98e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 635      |
# |    iterations         | 5500     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -7.04    |
# |    value_loss         | 771      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 635      |
# |    iterations         | 5600     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.677   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -5.99    |
# |    value_loss         | 175      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 635      |
# |    iterations         | 5700     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.201   |
# |    value_loss         | 0.095    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 633      |
# |    iterations         | 5800     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | 0.00117  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.831   |
# |    value_loss         | 7.55     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 632      |
# |    iterations         | 5900     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -30.5    |
# |    value_loss         | 4.72e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 633      |
# |    iterations         | 6000     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.678   |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -22.6    |
# |    value_loss         | 1e+03    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 6100     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.67    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 7.75     |
# |    value_loss         | 216      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 636      |
# |    iterations         | 6200     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 8.78     |
# |    value_loss         | 1.19e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 637       |
# |    iterations         | 6300      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -0.689    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -3.58     |
# |    value_loss         | 63.3      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 638      |
# |    iterations         | 6400     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 1.09     |
# |    value_loss         | 1.44e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 638      |
# |    iterations         | 6500     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.309   |
# |    value_loss         | 0.222    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 639      |
# |    iterations         | 6600     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.445    |
# |    value_loss         | 4.1      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 640      |
# |    iterations         | 6700     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.683   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -8       |
# |    value_loss         | 161      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 641      |
# |    iterations         | 6800     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 7.42     |
# |    value_loss         | 831      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 641      |
# |    iterations         | 6900     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.182   |
# |    value_loss         | 29.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 641      |
# |    iterations         | 7000     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.196   |
# |    value_loss         | 0.0837   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 642      |
# |    iterations         | 7100     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.677   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 5.77     |
# |    value_loss         | 93.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 642      |
# |    iterations         | 7200     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.669   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.203   |
# |    value_loss         | 0.0864   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 643      |
# |    iterations         | 7300     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 9.7      |
# |    value_loss         | 283      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 642      |
# |    iterations         | 7400     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.591   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.205   |
# |    value_loss         | 0.101    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 642      |
# |    iterations         | 7500     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.672   |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 1.92     |
# |    value_loss         | 19.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 643      |
# |    iterations         | 7600     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 1.43     |
# |    value_loss         | 41.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 643      |
# |    iterations         | 7700     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -0.683   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | -0.171   |
# |    value_loss         | 0.113    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 641      |
# |    iterations         | 7800     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 6.77     |
# |    value_loss         | 120      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 624      |
# |    iterations         | 7900     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.675   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | -0.249   |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 624      |
# |    iterations         | 8000     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | -12.9    |
# |    value_loss         | 843      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 624       |
# |    iterations         | 8100      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -0.687    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | 2.22      |
# |    value_loss         | 24        |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 625      |
# |    iterations         | 8200     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | -22.8    |
# |    value_loss         | 1.81e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 626       |
# |    iterations         | 8300      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -0.685    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | -5.17     |
# |    value_loss         | 83.7      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 626      |
# |    iterations         | 8400     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | -7.66    |
# |    value_loss         | 173      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 627      |
# |    iterations         | 8500     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.676   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | -0.551   |
# |    value_loss         | 3.67     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 627      |
# |    iterations         | 8600     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -0.673   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | -8.41    |
# |    value_loss         | 191      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 628      |
# |    iterations         | 8700     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 43500    |
# | train/                |          |
# |    entropy_loss       | -0.674   |
# |    explained_variance | 2.38e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | 6.51     |
# |    value_loss         | 170      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 628      |
# |    iterations         | 8800     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | 4.59     |
# |    value_loss         | 113      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 629      |
# |    iterations         | 8900     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 44500    |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | 1.35     |
# |    value_loss         | 975      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 629      |
# |    iterations         | 9000     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | 18.9     |
# |    value_loss         | 777      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 630       |
# |    iterations         | 9100      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -0.691    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -8.36     |
# |    value_loss         | 175       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# ...
# |    value_loss           | 8.8e+03     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 42           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0011677996 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.477       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.04e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000201     |
# |    value_loss           | 8.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 43           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0025405036 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.07e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.000107     |
# |    value_loss           | 8.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 44           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0039794785 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.455       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.63e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.00022      |
# |    value_loss           | 9.74e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 45          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.001988769 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.41       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.2e+03     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.000485    |
# |    value_loss           | 6.31e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 46           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 5.194047e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.21e+03     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.000368     |
# |    value_loss           | 9.53e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 721           |
# |    iterations           | 47            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00055899867 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.434        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.18e+03      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | 5.99e-05      |
# |    value_loss           | 9.6e+03       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 722           |
# |    iterations           | 48            |
# |    time_elapsed         | 136           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00033416948 |
# |    clip_fraction        | 0.0105        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.411        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.37e+03      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 0.000181      |
# |    value_loss           | 7.97e+03      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 49          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.001424888 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.43       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.18e+03    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00111     |
# |    value_loss           | 1.03e+04    |
# -----------------------------------------
# Using cpu device
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.626    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 9733     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.252    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 9855     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7700     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5460     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5024     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 5461     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 23616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 5776     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 27552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 6090     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 31488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 6346     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 35424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 6537     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 39360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 6713     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 43296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 6907     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 47232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 6091     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 51168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.98     |
# |    n_updates        | 291      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4428     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 55104    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.61     |
# |    n_updates        | 1275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3578     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 59040    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.05     |
# |    n_updates        | 2259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3022     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 62976    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.24     |
# |    n_updates        | 3243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2660     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 66912    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.82     |
# |    n_updates        | 4227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2414     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 70848    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.77     |
# |    n_updates        | 5211     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2228     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 74784    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.6     |
# |    n_updates        | 6195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2073     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 78720    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.27     |
# |    n_updates        | 7179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1964     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 82656    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.94     |
# |    n_updates        | 8163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1875     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 86592    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.34     |
# |    n_updates        | 9147     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1798     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 90528    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.58     |
# |    n_updates        | 10131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1737     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 94464    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.53     |
# |    n_updates        | 11115    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1670     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 98400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.1      |
# |    n_updates        | 12099    |
# ----------------------------------

# %%
env_A2C, info_A2C = tg.evaluation(df=amzn_data,model=model_A2C,frame_bound =(1000,1200))
env_PPO, info_PPO = tg.evaluation(df=amzn_data,model=model_PPO, frame_bound=(1000,1200))
env_DQN, info_DQN = tg.evaluation(df=amzn_data,model=model_DQN, frame_bound=(1000,1200))
for env in [env_A2C, env_PPO, env_DQN]:
    tg.graphique(env)
# Out:
# info {'total_reward': 32.930419921875, 'total_profit': 0.4701283669552427, 'position': 0}
# info {'total_reward': -223.41015625, 'total_profit': 0.7354834151649663, 'position': 1}
# info {'total_reward': 226.39990234375, 'total_profit': 0.9461180334964564, 'position': 1}
